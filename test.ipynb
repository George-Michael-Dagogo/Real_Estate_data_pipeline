# %%
pip install -r requirements.txt

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

url = 'https://www.propertypro.ng/property-for-short-let?sort=postedOn&order=desc'

titles= []
types = []
locations = []
prices = []
date_posted = []
PIDs = []
furnished = []
beds = []


def scraper_per_page(url):
    print('began')
    page = requests.get(url)
    soup = BeautifulSoup(page.text,  "html.parser")
    house_box = soup.find_all('div', class_ = "single-room-sale listings-property")
    for house in house_box:
#titles
        if house.find('h3', class_ = "listings-property-title2") is not None:
            title = house.find('h3', class_ = "listings-property-title2").text
            titles.append(title)
        else:
            titles.append('No title')

#types
        if house.find('h4', class_ = "listings-property-title") is not None:
            type = house.find('h4', class_ = "listings-property-title").text
            types.append(type)
        else:
            types.append('No type')

#locations
        if house.find('h4') is not None:
            locate = house.find_all('h4')
            location = locate[1].text
            locations.append(location)
        else:
            locations.append('No location')

#prices
        if house.find('h3', class_ = "listings-price") is not None:
            price = house.find('h3', class_ = "listings-price").text
            prices.append(price)
        else:
            prices.append('No price')

#date_posted
        if house.find('h5') is not None:
            date = house.find('h5').text
            date_posted.append(date)
        else:
            date_posted.append('No date')

#PIDs
        if house.find('h2') is not None:
            PID = house.find('h2').text.replace('PID:','')
            PIDs.append(PID)
        else:
            PIDs.append('No PID')

#furnished, serviced, newly built
        if house.find('div', class_ = "furnished-btn") is not None:
            furnish = house.find('div', class_ = "furnished-btn").text
            furnished.append(furnish)
        else:
            furnished.append('0')

#utilities
        if house.find('div', class_ = "fur-areea") is not None:
            bed = house.find('div', class_= "fur-areea").text.replace('\n',' ').strip()
            beds.append(bed)
        else:
            beds.append('No beds')


scraper_per_page(url)

df = pd.DataFrame({'title': titles, 
                        'categories': types,
                        'locations': locations,
                        'prices': prices,
                        'date_posted ': date_posted,
                        'PIDs': PIDs,
                        'furnished': furnished,
                        'beds': beds})
# Out:
# began

# %%
df
# Out:
#                                            title  \
# 0                     Modern 3 Bedroom Apartment
# 1                      Executive 4bedroom Duplex
# 2                Exquisite Two Bedroom Apartment
# 3                 Beautiful 3 Bedroom Waterfront
# 4                     Lux 5 Bedroom Duplex Ikoyi
# 5          Lovely 4 Bedroom Semi Detached Duplex
# 6                    Elegant 3 Bedroom Apartment
# 7                       Cozy 1 Bedroom Apartment
# 8                     Lovely 3 Bedroom Apartment
# 9                            3 Bedroom Apartment
# 10              Lovely 5 Bedroom Penthouse Oniru
# 11                 Beautiful 3 Bedroom Apartment
# 12                 Beautiful 2 Bedroom Apartment
# 13               2bedroom Flat At Llupeja Estate
# 14                    Modern 1 Bedroom Apartment
# 15                    Lovely 3 Bedroom Apartment
# 16             Cozy One Bedroom At Lekki Phase 1
# 17                    Lovely 2 Bedroom Apartment
# 18                      Lovely 2 Bedroom Gbagada
# 19                    Classy 3 Bedroom Apartment
# 20            2 Bedroom Available In Lekki Osapa
# 21                 Exquisite 3 Bedroom Apartment
# 22                    Lovely 3 Bedroom Apartment
# 23                      Cozy 3 Bedroom Apartment
# 24                 Exquisite 4 Bedroom Apartment
# 25                    Lovely 3 Bedroom Apartment
# 20                         Added 29 Jul 2023    1JWNZ
# 21                         Added 29 Jul 2023    8JWNY
# 22                         Added 29 Jul 2023    8JWNX
# 23                         Added 29 Jul 2023    2JWNX
# 24                         Added 29 Jul 2023    4JWNW
# 25                         Added 29 Jul 2023    9JWNU
# 26                         Added 29 Jul 2023    3JWNU
# 27                         Added 29 Jul 2023    6JWNQ
# 28                         Added 29 Jul 2023    2JWNP
# 29                         Added 29 Jul 2023    0JWNL
# 30                         Added 29 Jul 2023    0JWNK
# 31                         Added 29 Jul 2023    4JWNF
# 32                         Added 29 Jul 2023    2JWNE
# 33                         Added 29 Jul 2023    8JWND
# 34                         Added 29 Jul 2023    1JWND
# 35                         Added 29 Jul 2023    3JWNA
# 36                         Added 28 Jul 2023    4JWMC
# 37                         Added 28 Jul 2023    1JWLW
# 38                         Added 28 Jul 2023    7JWLU
# 39    Updated 28 Jul 2023, Added 28 Jul 2023    7JWLR
# 40                         Added 28 Jul 2023    2JWLN
# 41                         Added 28 Jul 2023    5JWLL
# 42                         Added 28 Jul 2023    4JWLJ
# 43                         Added 28 Jul 2023    8JWLH
# 44                         Added 28 Jul 2023    2JWLE
# 45                         Added 28 Jul 2023    1JWLD
# 46                         Added 28 Jul 2023    7JWLC
# 47                         Added 28 Jul 2023    2JWLC
# 48                         Added 28 Jul 2023    5JWKY
# 49                         Added 28 Jul 2023    7JWKW
#
#                                furnished                      beds
# 0                          \nFurnished\n  3 beds 3 baths 3 Toilets
# 1                          \nFurnished\n  4 beds 4 baths 5 Toilets
# 2                          \nFurnished\n  2 beds 2 baths 2 Toilets
# 3                          \nFurnished\n  3 beds 3 baths 3 Toilets
# 4                \nFurnished\nServiced\n  5 beds 5 baths 5 Toilets
# 5                          \nFurnished\n  4 beds 4 baths 4 Toilets
# 6                          \nFurnished\n  3 beds 3 baths 3 Toilets
# 7                          \nFurnished\n  1 beds 1 baths 1 Toilets
# 8                          \nFurnished\n  3 beds 3 baths 3 Toilets
# 9                \nFurnished\nServiced\n  3 beds 3 baths 4 Toilets
# 10                         \nFurnished\n  5 beds 5 baths 5 Toilets
# 11                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 12                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 13                                    \n  2 beds 3 baths 3 Toilets
# 14                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 15                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 16               \nFurnished\nServiced\n  1 beds 1 baths 1 Toilets
# 17                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 18  \nFurnished\nServiced\nNewly Built\n  2 beds 2 baths 2 Toilets
# 19                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 20  \nFurnished\nServiced\nNewly Built\n  2 beds 2 baths 2 Toilets
# 21                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 22                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 23                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 24                         \nFurnished\n  4 beds 4 baths 4 Toilets
# 25                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 26                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 27                         \nFurnished\n  5 beds 5 baths 5 Toilets
# 28                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 29                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 30                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 31                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 32                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 33                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 34                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 35                       \nNewly Built\n  2 beds 2 baths 3 Toilets
# 36                                    \n  1 beds 1 baths 1 Toilets
# 37                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 38                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 39                                    \n    4 beds  baths  Toilets
# 40                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 41                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 42                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 43                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 44                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 45                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 46                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 47                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 48                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 49                         \nFurnished\n  4 beds 4 baths 4 Toilets
