# %%
pip install -r requirements.txt

# %% [markdown]
# ## Short Let

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re


url = [f'https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page={i:d}'  for i in (range(0, 67))]


titles= []
types = []
locations = []
prices = []
date_posted = []
PIDs = []
furnished = []
beds = []
agents = []


def extract_data(url):
    print('began')
    page = requests.get(url)
    soup = BeautifulSoup(page.text,  "html.parser")
    house_box = soup.find_all('div', class_ = "single-room-sale listings-property")
    for house in house_box:
#titles
        if house.find('h3', class_ = "listings-property-title2") is not None:
            title = house.find('h3', class_ = "listings-property-title2").text
            titles.append(title)
        else:
            titles.append('No title')

#types
        if house.find('h4', class_ = "listings-property-title") is not None:
            type = house.find('h4', class_ = "listings-property-title").text
            types.append(type)
        else:
            types.append('No type')

#locations
        if house.find('h4') is not None:
            locate = house.find_all('h4')
            location = locate[1].text
            locations.append(location)
        else:
            locations.append('No location')

#prices
        if house.find('h3', class_ = "listings-price") is not None:
            price = house.find('h3', class_ = "listings-price").text
            prices.append(price)
        else:
            prices.append('No price')

#date_posted
        if house.find('h5') is not None:
            date = house.find('h5').text
            date_posted.append(date)
        else:
            date_posted.append('No date')

#PIDs
        if house.find('h2') is not None:
            PID = house.find('h2').text.replace('PID:','')
            PIDs.append(PID)
        else:
            PIDs.append('No PID')

#furnished, serviced, newly built
        if house.find('div', class_ = "furnished-btn") is not None:
            furnish = house.find('div', class_ = "furnished-btn").text
            furnished.append(furnish)
        else:
            furnished.append('0')

#utilities
        if house.find('div', class_ = "fur-areea") is not None:
            bed = house.find('div', class_= "fur-areea").text.replace('\n',' ').strip()
            beds.append(bed)
        else:
            beds.append('No beds')
        
#agents
        if house.find('div', class_ = "elite-icon") is not None:
            agent = house.find('div', class_ = "elite-icon").a.get('href')
            agent = agent.replace('/agent/','')
            agents.append(agent)
        else:
            agents.append('No agent')


def transform_data():
    df = pd.DataFrame({'title': titles, 
                            'categories': types,
                            'address': locations,
                            'agent': agents,
                            'price': prices,
                            'date_post': date_posted,
                            'PIDs': PIDs,
                            'furnish': furnished,
                            'bed': beds})

    df['newly_built'] = df['furnish'].apply(lambda text: 'Newly Built' in text)
    df['serviced'] = df['furnish'].apply(lambda text: 'Serviced' in text)
    df['furnished'] = df['furnish'].apply(lambda text: 'Furnished' in text)
    df.drop('furnish', axis=1, inplace=True)
    df[['beds', 'baths', 'toilets']] = df['bed'].str.extract(r'(\d+)\s*beds?\s*(\d*)\s*baths?\s*(\d*)\s*Toilets?')
    df['beds'] = pd.to_numeric(df['beds'], errors='coerce').fillna(0).astype(int)
    df['baths'] = pd.to_numeric(df['baths'], errors='coerce').fillna(0).astype(int)
    df['toilets'] = pd.to_numeric(df['toilets'], errors='coerce').fillna(0).astype(int)

    df['price'] = df['price'].str.replace('₦', '')

    df['price_int'] = pd.to_numeric(df['price'].str.replace(',', '').str.extract(r'(\d+)')[0])

    df['price_per_day_₦'] = df['price_per_month_₦'] = df['price_per_year_₦'] = pd.NA

    for index, row in df.iterrows():
        if 'day' in row['price']:
            df.at[index, 'price_per_month_₦'] = row['price_int'] * 30
            df.at[index, 'price_per_year_₦'] = row['price_int'] * 365
            df.at[index, 'price_per_day_₦'] = row['price_int']
        elif 'month' in row['price']:
            df.at[index, 'price_per_day_₦'] = row['price_int'] / 30
            df.at[index, 'price_per_year_₦'] = row['price_int'] * 12
            df.at[index, 'price_per_month_₦'] = row['price_int']
        elif 'year' in row['price']:
            df.at[index, 'price_per_month_₦'] = row['price_int'] / 12
            df.at[index, 'price_per_day_₦'] = row['price_int'] / 365
            df.at[index, 'price_per_year_₦'] = row['price_int']
        else:
            df.at[index, 'price_per_year_₦'] = row['price_int'] * 365
            df.at[index, 'price_per_month_₦'] = row['price_int'] * 12
            df.at[index, 'price_per_day_₦'] = row['price_int']

    df.drop('price_int', axis=1, inplace=True)
    df.drop('bed', axis=1, inplace=True)

    df['date_posted'] = df['date_post'].str.extract(r'Added (\d{2} \w{3} \d{4})', expand=False)
    df['date_updated'] = df['date_post'].str.extract(r'Updated (\d{2} \w{3} \d{4})', expand=False)
    df['date_posted'] = pd.to_datetime(df['date_posted'], format='%d %b %Y')
    df['date_updated'] = pd.to_datetime(df['date_updated'], format='%d %b %Y')
    df.drop('date_post', axis=1, inplace=True)
    df['state'] = df['address'].str.split().str[-1]
    df.to_csv('propertypro_short_let.csv', index=False)

for i in url:
    print(i)
    extract_data(i)

transform_data()

# %% [markdown]
# ## For sale

# %%
url = [f'https://www.propertypro.ng/property-for-sale?sort=postedOn&order=desc&page={i:d}'  for i in (range(0, 865))]
titles= []
types = []
locations = []
prices = []
date_posted = []
PIDs = []
furnished = []
beds = []
agents = []


def extract_data(url):
    print('began')
    page = requests.get(url)
    soup = BeautifulSoup(page.text,  "html.parser")
    house_box = soup.find_all('div', class_ = "single-room-sale listings-property")
    for house in house_box:
#titles
        if house.find('h3', class_ = "listings-property-title2") is not None:
            title = house.find('h3', class_ = "listings-property-title2").text
            titles.append(title)
        else:
            titles.append('No title')

#types
        if house.find('h4', class_ = "listings-property-title") is not None:
            type = house.find('h4', class_ = "listings-property-title").text
            types.append(type)
        else:
            types.append('No type')

#locations
        if house.find('h4') is not None:
            locate = house.find_all('h4')
            location = locate[1].text
            locations.append(location)
        else:
            locations.append('No location')

#prices
        if house.find('h3', class_ = "listings-price") is not None:
            price = house.find('h3', class_ = "listings-price").text
            prices.append(price)
        else:
            prices.append('No price')

#date_posted
        if house.find('h5') is not None:
            date = house.find('h5').text
            date_posted.append(date)
        else:
            date_posted.append('No date')

#PIDs
        if house.find('h2') is not None:
            PID = house.find('h2').text.replace('PID:','')
            PIDs.append(PID)
        else:
            PIDs.append('No PID')

#furnished, serviced, newly built
        if house.find('div', class_ = "furnished-btn") is not None:
            furnish = house.find('div', class_ = "furnished-btn").text
            furnished.append(furnish)
        else:
            furnished.append('0')

#utilities
        if house.find('div', class_ = "fur-areea") is not None:
            bed = house.find('div', class_= "fur-areea").text.replace('\n',' ').strip()
            beds.append(bed)
        else:
            beds.append('No beds')
        
#agents
        if house.find('div', class_ = "elite-icon") is not None:
            agent = house.find('div', class_ = "elite-icon").a.get('href')
            agent = agent.replace('/agent/','')
            agents.append(agent)
        else:
            agents.append('No agent')


def transform_data():
    df = pd.DataFrame({'title': titles, 
                            'categories': types,
                            'address': locations,
                            'agent': agents,
                            'price': prices,
                            'date_post': date_posted,
                            'PIDs': PIDs,
                            'furnish': furnished,
                            'bed': beds})

    df['newly_built'] = df['furnish'].apply(lambda text: 'Newly Built' in text)
    df['serviced'] = df['furnish'].apply(lambda text: 'Serviced' in text)
    df['furnished'] = df['furnish'].apply(lambda text: 'Furnished' in text)
    df.drop('furnish', axis=1, inplace=True)
    df[['beds', 'baths', 'toilets']] = df['bed'].str.extract(r'(\d+)\s*beds?\s*(\d*)\s*baths?\s*(\d*)\s*Toilets?')
    df['beds'] = pd.to_numeric(df['beds'], errors='coerce').fillna(0).astype(int)
    df['baths'] = pd.to_numeric(df['baths'], errors='coerce').fillna(0).astype(int)
    df['toilets'] = pd.to_numeric(df['toilets'], errors='coerce').fillna(0).astype(int)

    df['price'] = df['price'].str.replace('₦', '')

    df['price_₦'] = pd.to_numeric(df['price'].str.replace(',', '').str.extract(r'(\d+)')[0])

    
    df.drop('price', axis=1, inplace=True)
    df.drop('bed', axis=1, inplace=True)

    df['date_posted'] = df['date_post'].str.extract(r'Added (\d{2} \w{3} \d{4})', expand=False)
    df['date_updated'] = df['date_post'].str.extract(r'Updated (\d{2} \w{3} \d{4})', expand=False)
    df['date_posted'] = pd.to_datetime(df['date_posted'], format='%d %b %Y')
    df['date_updated'] = pd.to_datetime(df['date_updated'], format='%d %b %Y')
    df['date_updated'] = df['date_updated'].fillna("not updated")
    df.drop('date_post', axis=1, inplace=True)
    df['state'] = df['address'].str.split().str[-1]
    df.to_csv('propertypro_for_sale.csv', index=False)
    

for i in url:
    print(i)
    extract_data(i)

transform_data()

# %% [markdown]
# ## For Rent

# %%
url = [f'https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page={i:d}'  for i in (range(0, 424))]
titles= []
types = []
locations = []
prices = []
date_posted = []
PIDs = []
furnished = []
beds = []
agents = []


def extract_data(url):
    print('began')
    page = requests.get(url)
    soup = BeautifulSoup(page.text,  "html.parser")
    house_box = soup.find_all('div', class_ = "single-room-sale listings-property")
    for house in house_box:
#titles
        if house.find('h3', class_ = "listings-property-title2") is not None:
            title = house.find('h3', class_ = "listings-property-title2").text
            titles.append(title)
        else:
            titles.append('No title')

#types
        if house.find('h4', class_ = "listings-property-title") is not None:
            type = house.find('h4', class_ = "listings-property-title").text
            types.append(type)
        else:
            types.append('No type')

#locations
        if house.find('h4') is not None:
            locate = house.find_all('h4')
            location = locate[1].text
            locations.append(location)
        else:
            locations.append('No location')

#prices
        if house.find('h3', class_ = "listings-price") is not None:
            price = house.find('h3', class_ = "listings-price").text
            prices.append(price)
        else:
            prices.append('No price')

#date_posted
        if house.find('h5') is not None:
            date = house.find('h5').text
            date_posted.append(date)
        else:
            date_posted.append('No date')

#PIDs
        if house.find('h2') is not None:
            PID = house.find('h2').text.replace('PID:','')
            PIDs.append(PID)
        else:
            PIDs.append('No PID')

#furnished, serviced, newly built
        if house.find('div', class_ = "furnished-btn") is not None:
            furnish = house.find('div', class_ = "furnished-btn").text
            furnished.append(furnish)
        else:
            furnished.append('0')

#utilities
        if house.find('div', class_ = "fur-areea") is not None:
            bed = house.find('div', class_= "fur-areea").text.replace('\n',' ').strip()
            beds.append(bed)
        else:
            beds.append('No beds')
        
#agents
        if house.find('div', class_ = "elite-icon") is not None:
            agent = house.find('div', class_ = "elite-icon").a.get('href')
            agent = agent.replace('/agent/','')
            agents.append(agent)
        else:
            agents.append('No agent')


def transform_data():
    df = pd.DataFrame({'title': titles, 
                            'categories': types,
                            'address': locations,
                            'agent': agents,
                            'price': prices,
                            'date_post': date_posted,
                            'PIDs': PIDs,
                            'furnish': furnished,
                            'bed': beds})

    df['newly_built'] = df['furnish'].apply(lambda text: 'Newly Built' in text)
    df['serviced'] = df['furnish'].apply(lambda text: 'Serviced' in text)
    df['furnished'] = df['furnish'].apply(lambda text: 'Furnished' in text)
    df.drop('furnish', axis=1, inplace=True)
    df[['beds', 'baths', 'toilets']] = df['bed'].str.extract(r'(\d+)\s*beds?\s*(\d*)\s*baths?\s*(\d*)\s*Toilets?')
    df['beds'] = pd.to_numeric(df['beds'], errors='coerce').fillna(0).astype(int)
    df['baths'] = pd.to_numeric(df['baths'], errors='coerce').fillna(0).astype(int)
    df['toilets'] = pd.to_numeric(df['toilets'], errors='coerce').fillna(0).astype(int)

    df['price'] = df['price'].str.replace('₦', '')

    df['price_₦_yearly'] = pd.to_numeric(df['price'].str.replace(',', '').str.extract(r'(\d+)')[0])

    
    df.drop('price', axis=1, inplace=True)
    df.drop('bed', axis=1, inplace=True)

    df['date_posted'] = df['date_post'].str.extract(r'Added (\d{2} \w{3} \d{4})', expand=False)
    df['date_updated'] = df['date_post'].str.extract(r'Updated (\d{2} \w{3} \d{4})', expand=False)
    df['date_posted'] = pd.to_datetime(df['date_posted'], format='%d %b %Y')
    df['date_updated'] = pd.to_datetime(df['date_updated'], format='%d %b %Y')
    df['date_updated'] = df['date_updated'].fillna("not updated")
    df.drop('date_post', axis=1, inplace=True)
    df['state'] = df['address'].str.split().str[-1]
    df.to_csv('propertypro_for_rent.csv', index=False)
    return df
    

for i in url:
    print(i)
    extract_data(i)

transform_data()
# Out:
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=0
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=1
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=2
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=3
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=4
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=5
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=6
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=7
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=8
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=9
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=10
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=11
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=12
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=13
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=14
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=15
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=16
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=17
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=18
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=19
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=20
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=21
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=22
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=23
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=24
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=25
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=26
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=27
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=28
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=29
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=30
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=31
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=32
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=33
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=34
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=35
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=36
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=37
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=38
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=39
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=40
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=41
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=42
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=43
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=44
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=45
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=46
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=47
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=48
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=49
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=50
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=51
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=52
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=53
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=54
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=55
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=56
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=57
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=58
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=59
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=60
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=61
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=62
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=63
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=64
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=65
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=66
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=67
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=68
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=69
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=70
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=71
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=72
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=73
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=74
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=75
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=76
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=77
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=78
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=79
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=80
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=81
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=82
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=83
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=84
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=85
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=86
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=87
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=88
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=89
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=90
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=91
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=92
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=93
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=94
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=95
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=96
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=97
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=98
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=99
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=100
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=101
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=102
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=103
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=104
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=105
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=106
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=107
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=108
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=109
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=110
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=111
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=112
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=113
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=114
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=115
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=116
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=117
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=118
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=119
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=120
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=121
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=122
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=123
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=124
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=125
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=126
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=127
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=128
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=129
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=130
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=131
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=132
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=133
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=134
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=135
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=136
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=137
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=138
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=139
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=140
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=141
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=142
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=143
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=144
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=145
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=146
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=147
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=148
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=149
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=150
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=151
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=152
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=153
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=154
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=155
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=156
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=157
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=158
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=159
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=160
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=161
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=162
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=163
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=164
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=165
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=166
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=167
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=168
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=169
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=170
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=171
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=172
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=173
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=174
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=175
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=176
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=177
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=178
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=179
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=180
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=181
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=182
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=183
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=184
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=185
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=186
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=187
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=188
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=189
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=190
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=191
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=192
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=193
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=194
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=195
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=196
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=197
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=198
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=199
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=200
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=201
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=202
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=203
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=204
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=205
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=206
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=207
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=208
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=209
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=210
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=211
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=212
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=213
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=214
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=215
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=216
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=217
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=218
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=219
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=220
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=221
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=222
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=223
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=224
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=225
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=226
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=227
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=228
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=229
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=230
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=231
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=232
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=233
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=234
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=235
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=236
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=237
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=238
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=239
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=240
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=241
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=242
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=243
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=244
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=245
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=246
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=247
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=248
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=249
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=250
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=251
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=252
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=253
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=254
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=255
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=256
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=257
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=258
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=259
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=260
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=261
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=262
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=263
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=264
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=265
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=266
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=267
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=268
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=269
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=270
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=271
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=272
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=273
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=274
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=275
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=276
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=277
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=278
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=279
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=280
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=281
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=282
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=283
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=284
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=285
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=286
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=287
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=288
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=289
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=290
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=291
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=292
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=293
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=294
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=295
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=296
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=297
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=298
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=299
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=300
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=301
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=302
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=303
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=304
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=305
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=306
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=307
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=308
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=309
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=310
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=311
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=312
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=313
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=314
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=315
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=316
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=317
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=318
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=319
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=320
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=321
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=322
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=323
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=324
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=325
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=326
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=327
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=328
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=329
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=330
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=331
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=332
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=333
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=334
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=335
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=336
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=337
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=338
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=339
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=340
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=341
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=342
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=343
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=344
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=345
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=346
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=347
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=348
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=349
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=350
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=351
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=352
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=353
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=354
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=355
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=356
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=357
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=358
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=359
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=360
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=361
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=362
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=363
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=364
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=365
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=366
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=367
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=368
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=369
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=370
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=371
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=372
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=373
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=374
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=375
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=376
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=377
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=378
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=379
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=380
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=381
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=382
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=383
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=384
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=385
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=386
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=387
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=388
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=389
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=390
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=391
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=392
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=393
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=394
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=395
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=396
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=397
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=398
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=399
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=400
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=401
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=402
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=403
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=404
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=405
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=406
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=407
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=408
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=409
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=410
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=411
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=412
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=413
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=414
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=415
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=416
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=417
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=418
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=419
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=420
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=421
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=422
# began
# https://www.propertypro.ng/property-for-rent?sort=postedOn&order=desc&page=423
# began
#                                                    title  \
# 0                A Luxuriously Built 2 Bedroom Apartment
# 1          Newly Built Mini Flat In A Serene Environment
# 2               Sharp Two Bedroom Apartment In An Estate
# 3                        Newly Built 2 Bedroom Apartment
# 4          Beautiful Luxury Serviced 1 Bedroom Apartment
# ...                                                  ...
# 21160  A Tastefully Finished 5bedroom Fully Detached ...
# 21161      Newly Built Mini Flat In A Serene Environment
# 21162                  Brand New 4bedroom Terrace Duplex
# 21163                         Newly Built 2 Bedroom Flat
# 21164                         Newly Built 2 Bedroom Flat
#
#                                               categories  \
# 0                               2 BEDROOM HOUSE FOR RENT
# 1                    1 BEDROOM FLAT / APARTMENT FOR RENT
# 2                    2 BEDROOM FLAT / APARTMENT FOR RENT
# 3                    2 BEDROOM FLAT / APARTMENT FOR RENT
# 4                               1 BEDROOM HOUSE FOR RENT
# ...                                                  ...
# 21160           5 BEDROOM DETACHED DUPLEX HOUSE FOR RENT
# 21161  1 BEDROOM MINI FLAT MINI FLAT FLAT / APARTMENT...
# 21162           4 BEDROOM TERRACED DUPLEX HOUSE FOR RENT
# 21163                2 BEDROOM FLAT / APARTMENT FOR RENT
# 21164                2 BEDROOM FLAT / APARTMENT FOR RENT
#
#                                             address  \
# 0          Ilasan Elegushi Lekki Ilasan Lekki Lagos
# 1                             Ifako Ogba Ogba Lagos
# 2         Peacevile Estate Badore Badore Ajah Lagos
# 3                             Ifako Ogba Ogba Lagos
# 4                         Lekki Phase 1 Lekki Lagos
# ...                                             ...
# 21160                      Jabi District Jabi Abuja
# 21161  Lerato Ahmadiyya Abule Egba Abule Egba Lagos
# 21162                     2nd Toll Gate Lekki Lagos
# 21163            Ebute Metta Ebute Metta Yaba Lagos
# 21164            Ebute Metta Ebute Metta Yaba Lagos
#
#                                 agent    PIDs  newly_built  serviced  \
# 0                   chukwuemeka-felix   6JXDL         True      True
# 1         city-garden-real-estate-ltd   5JXDL        False     False
# 2                                 156   4JXDL        False     False
# 3         city-garden-real-estate-ltd   3JXDL         True     False
# 4                          sanrealtor   2JXDL         True      True
# ...                               ...     ...          ...       ...
# 21160                  austelright-co   4EMYX        False     False
# 21161  tobbylex-properties-consultant   4EDUC         True     False
# 21162                         gideon4   4DSGL        False      True
# 21163                   stephen-ogweh   1DRGW         True     False
# 21164                   stephen-ogweh   0DRGW         True     False
#
#        furnished  beds  baths  toilets  price_₦_yearly date_posted  \
# 0          False     2      2        3         3200000  2023-08-02
# 1          False     1      0        0          500000  2023-08-02
# 2          False     2      0        0         1500000  2023-08-02
# 3          False     2      0        0         1000000  2023-08-02
# 4          False     1      1        2         4000000  2023-08-02
# ...          ...   ...    ...      ...             ...         ...
# 21160      False     5      5        6        12000000  2021-04-07
# 21161       True     1      1        1          250000  2021-01-04
# 21162      False     4      4        5         3000000  2020-08-10
# 21163      False     2      2        2          800000  2020-08-03
# 21164      False     2      2        2          800000  2020-08-03
#
#       date_updated  state
# 0      not updated  Lagos
# 1      not updated  Lagos
# 2      not updated  Lagos
# 3      not updated  Lagos
# 4      not updated  Lagos
# ...            ...    ...
# 21160  not updated  Abuja
# 21161  not updated  Lagos
# 21162  not updated  Lagos
# 21163  not updated  Lagos
# 21164  not updated  Lagos
#
# [21165 rows x 15 columns]
