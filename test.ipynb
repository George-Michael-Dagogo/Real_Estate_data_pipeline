# %%
pip install -r requirements.txt

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re


url = [f'https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page={i:d}'  for i in (range(0, 67))]


titles= []
types = []
locations = []
prices = []
date_posted = []
PIDs = []
furnished = []
beds = []


def extract_data(url):
    print('began')
    page = requests.get(url)
    soup = BeautifulSoup(page.text,  "html.parser")
    house_box = soup.find_all('div', class_ = "single-room-sale listings-property")
    for house in house_box:
#titles
        if house.find('h3', class_ = "listings-property-title2") is not None:
            title = house.find('h3', class_ = "listings-property-title2").text
            titles.append(title)
        else:
            titles.append('No title')

#types
        if house.find('h4', class_ = "listings-property-title") is not None:
            type = house.find('h4', class_ = "listings-property-title").text
            types.append(type)
        else:
            types.append('No type')

#locations
        if house.find('h4') is not None:
            locate = house.find_all('h4')
            location = locate[1].text
            locations.append(location)
        else:
            locations.append('No location')

#prices
        if house.find('h3', class_ = "listings-price") is not None:
            price = house.find('h3', class_ = "listings-price").text
            prices.append(price)
        else:
            prices.append('No price')

#date_posted
        if house.find('h5') is not None:
            date = house.find('h5').text
            date_posted.append(date)
        else:
            date_posted.append('No date')

#PIDs
        if house.find('h2') is not None:
            PID = house.find('h2').text.replace('PID:','')
            PIDs.append(PID)
        else:
            PIDs.append('No PID')

#furnished, serviced, newly built
        if house.find('div', class_ = "furnished-btn") is not None:
            furnish = house.find('div', class_ = "furnished-btn").text
            furnished.append(furnish)
        else:
            furnished.append('0')

#utilities
        if house.find('div', class_ = "fur-areea") is not None:
            bed = house.find('div', class_= "fur-areea").text.replace('\n',' ').strip()
            beds.append(bed)
        else:
            beds.append('No beds')


def transform_data():
    df = pd.DataFrame({'title': titles, 
                            'categories': types,
                            'address': locations,
                            'price': prices,
                            'date_posted': date_posted,
                            'PIDs': PIDs,
                            'furnish': furnished,
                            'bed': beds})

    df['newly_built'] = df['furnish'].apply(lambda text: 'Newly Built' in text)
    df['serviced'] = df['furnish'].apply(lambda text: 'Serviced' in text)
    df['furnished'] = df['furnish'].apply(lambda text: 'Furnished' in text)
    df.drop('furnish', axis=1, inplace=True)
    df[['beds', 'baths', 'toilets']] = df['bed'].str.extract(r'(\d+)\s*beds?\s*(\d*)\s*baths?\s*(\d*)\s*Toilets?')
    df['beds'] = df['beds'].replace('', 0).astype(int)
    df['baths'] = df['baths'].replace('', 0).astype(int)
    df['toilets'] = df['toilets'].replace('', 0).astype(int)
    df['price'] = df['price'].str.replace('₦', '')

    df['price_int'] = pd.to_numeric(df['price'].str.replace(',', '').str.extract(r'(\d+)')[0])

    df['price_per_day_₦'] = df['price_per_month_₦'] = df['price_per_year_₦'] = pd.NA

    for index, row in df.iterrows():
        if 'day' in row['price']:
            df.at[index, 'price_per_month_₦'] = row['price_int'] * 30
            df.at[index, 'price_per_year_₦'] = row['price_int'] * 365
            df.at[index, 'price_per_day_₦'] = row['price_int']
        elif 'month' in row['price']:
            df.at[index, 'price_per_day_₦'] = row['price_int'] / 30
            df.at[index, 'price_per_year_₦'] = row['price_int'] * 12
            df.at[index, 'price_per_month_₦'] = row['price_int']
        elif 'year' in row['price']:
            df.at[index, 'price_per_month_₦'] = row['price_int'] / 12
            df.at[index, 'price_per_day_₦'] = row['price_int'] / 365
            df.at[index, 'price_per_year_₦'] = row['price_int']
        else:
            df.at[index, 'price_per_year_₦'] = row['price_int'] * 365
            df.at[index, 'price_per_month_₦'] = row['price_int'] * 12
            df.at[index, 'price_per_day_₦'] = row['price_int']

    df.drop('price_int', axis=1, inplace=True)

    df['date_posted'] = df['date_posted'].str.extract(r'Added (\d{2} \w{3} \d{4})', expand=False)
    df['date_posted'] = pd.to_datetime(df['date_posted'], format='%d %b %Y')
    df['state'] = df['address'].str.split().str[-1]
    df.to_csv('propertypro_short_let.csv', index=False)

for i in url:
    print(i)
    extract_data(i)

transform_data()
# Out:
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=0
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=1
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=2
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=3
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=4
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=5
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=6
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=7
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=8
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=9
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=10
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=11
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=12
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=13
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=14
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=15
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=16
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=17
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=18
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=19
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=20
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=21
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=22
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=23
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=24
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=25
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=26
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=27
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=28
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=29
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=30
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=31
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=32
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=33
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=34
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=35
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=36
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=37
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=38
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=39
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=40
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=41
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=42
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=43
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=44
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=45
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=46
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=47
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=48
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=49
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=50
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=51
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=52
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=53
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=54
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=55
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=56
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=57
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=58
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=59
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=60
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=61
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=62
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=63
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=64
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=65
# began
# https://www.propertypro.ng/property-for-short-let?sort=beds&order=desc&page=66
# began

# %%
print(beds)
# Out:
# ['5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 0 baths 0 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 10 baths 10 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 6 baths 6 Toilets', '5 beds 6 baths 6 Toilets', '5 beds 6 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 4 baths 0 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 0 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 6 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 0 baths 0 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 0 baths 0 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 4 baths 4 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 4 Toilets', '5 beds 5 baths 5 Toilets', '5 beds 5 baths 5 Toilets', '5 beds  baths  Toilets', '5 beds 6 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 0 baths 0 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 6 Toilets', '5 beds 5 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 5 baths 5 Toilets', '4 beds 5 baths 5 Toilets', '4 beds 3 baths 4 Toilets', '4 beds 3 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 5 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds  baths  Toilets', '4 beds 4 baths 5 Toilets', '4 beds 5 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 0 baths 0 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 3 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 5 baths 0 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 1 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 3 baths 3 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 8 baths 8 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 0 baths 0 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 6 baths 6 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 1 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 4 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets', '4 beds 4 baths 5 Toilets ...

# %%
df
# Out:
#                                            title  \
# 0                     Modern 3 Bedroom Apartment
# 1                     Executive 4 Bedroom Duplex
# 2                   Exquisite2 Bedroom Apartment
# 3                 Waterfront 3 Bedroom Apartment
# 4               Luxury 5 Bedroom Detached Duplex
# 5          Lovely 4 Bedroom Semi Detached Duplex
# 6                    Elegant 3 Bedroom Apartment
# 7                       Cozy 1 Bedroom Apartment
# 8                     Lovely 3 Bedroom Apartment
# 9                  Luxurious 3 Bedroom Apartment
# 10                           3 Bedroom Apartment
# 11                    Lovely 5 Bedroom Penthouse
# 12                 Beautiful 3 Bedroom Apartment
# 13                 Beautiful 2 Bedroom Apartment
# 14                                2 Bedroom Flat
# 15                    Modern 1 Bedroom Apartment
# 16                    Lovely 3 Bedroom Apartment
# 17                           1 Bedroom Apartment
# 18                    Lovely 2 Bedroom Apartment
# 19                    Lovely 2 Bedroom Apartment
# 20                    Classy 3 Bedroom Apartment
# 21                           2 Bedroom Apartment
# 22                 Exquisite 3 Bedroom Apartment
# 23                    Lovely 3 Bedroom Apartment
# 24                      Cozy 3 Bedroom Apartment
# 25                 Exquisite 4 Bedroom Apartment
# 26                    Lovely 3 Bedroom Apartment
# 27                  Standard 1 Bedroom Apartment
# 28                           5 Bedroom Apartment
# 26                                  Ikate Lekki Lagos   ₦ 120,000/day
# 27                               Aguda Surulere Lagos    ₦ 58,000/day
# 28                                  Ikate Lekki Lagos   ₦ 155,000/day
# 29                             Ogudu Road Ojota Lagos    ₦ 95,000/day
# 30                                       Wuse 2 Abuja    ₦ 70,000/day
# 31                          Lekki Phase 1 Lekki Lagos    ₦ 82,000/day
# 32                        Parkview Estate Ikoyi Lagos   ₦ 155,000/day
# 33                               Phase 1, Lekki Lagos    ₦ 76,000/day
# 34                               Phase 1, Lekki Lagos    ₦ 82,000/day
# 35                               Maryland Ikeja Lagos   ₦ 100,000/day
# 36  Nicon Junction, Opposite Maitama Main, Katampe...    ₦ 80,000/day
# 37                                         Ketu Lagos    ₦ 46,000/day
# 38                                  Ikate Lekki Lagos   ₦ 120,000/day
# 39                             Bourdillon Ikoyi Lagos   ₦ 190,000/day
# 40              Amuwo Amuwo Odofin Amuwo Odofin Lagos       ₦ 170,000
# 41                          Lekki Phase 1 Lekki Lagos    ₦ 65,000/day
# 42                          Lekki Phase 1 Lekki Lagos   ₦ 120,000/day
# 43                           Osapa London Lekki Lagos    ₦ 80,000/day
# 44                                        Lekki Lagos   ₦ 100,000/day
# 45                          Lekki Phase 1 Lekki Lagos    ₦ 82,000/day
# 46                                         Ajah Lagos    ₦ 75,000/day
# 47                                         Ajah Lagos    ₦ 65,000/day
# 48                                  Ikate Lekki Lagos    ₦ 85,000/day
# 49                          Lekki Phase 2 Lekki Lagos    ₦ 92,000/day
#
#                                  date_posted     PIDs  \
# 0                          Added 30 Jul 2023    8JWRS
# 1                          Added 30 Jul 2023    6JWRR
# 2                          Added 30 Jul 2023    9JWRQ
# 3                          Added 30 Jul 2023    7JWRN
# 4     Updated 30 Jul 2023, Added 30 Jul 2023    7JWRK
# 5                          Added 30 Jul 2023    2JWRJ
# 6                          Added 30 Jul 2023    3JWRH
# 7                          Added 30 Jul 2023    0JWRC
# 8                          Added 30 Jul 2023    1JWQY
# 9     Updated 31 Jul 2023, Added 30 Jul 2023    7JWQR
# 10                         Added 30 Jul 2023    1JWQJ
# 11                         Added 29 Jul 2023    4JWPQ
# 12                         Added 29 Jul 2023    1JWPQ
# 13                         Added 29 Jul 2023    3JWPP
# 14                         Added 29 Jul 2023    0JWPM
# 15                         Added 29 Jul 2023    1JWPL
# 16                         Added 29 Jul 2023    2JWPE
# 17                         Added 29 Jul 2023    3JWPC
# 18                         Added 29 Jul 2023    7JWPA
# 19                         Added 29 Jul 2023    0JWPA
# 20                         Added 29 Jul 2023    9JWNZ
# 21                         Added 29 Jul 2023    1JWNZ
# 22                         Added 29 Jul 2023    8JWNY
# 23                         Added 29 Jul 2023    8JWNX
# 24                         Added 29 Jul 2023    2JWNX
# 25                         Added 29 Jul 2023    4JWNW
# 26                         Added 29 Jul 2023    9JWNU
# 27                         Added 29 Jul 2023    3JWNU
# 28                         Added 29 Jul 2023    6JWNQ
# 29                         Added 29 Jul 2023    2JWNP
# 30                         Added 29 Jul 2023    0JWNL
# 31                         Added 29 Jul 2023    0JWNK
# 32                         Added 29 Jul 2023    4JWNF
# 33                         Added 29 Jul 2023    2JWNE
# 34                         Added 29 Jul 2023    8JWND
# 35                         Added 29 Jul 2023    1JWND
# 36    Updated 31 Jul 2023, Added 29 Jul 2023    3JWNA
# 37                         Added 28 Jul 2023    4JWMC
# 38                         Added 28 Jul 2023    1JWLW
# 39                         Added 28 Jul 2023    7JWLU
# 40    Updated 28 Jul 2023, Added 28 Jul 2023    7JWLR
# 41                         Added 28 Jul 2023    2JWLN
# 42                         Added 28 Jul 2023    5JWLL
# 43                         Added 28 Jul 2023    4JWLJ
# 44                         Added 28 Jul 2023    8JWLH
# 45                         Added 28 Jul 2023    2JWLE
# 46                         Added 28 Jul 2023    1JWLD
# 47                         Added 28 Jul 2023    7JWLC
# 48                         Added 28 Jul 2023    2JWLC
# 49                         Added 28 Jul 2023    5JWKY
#
#                                  furnish                      beds  \
# 0                          \nFurnished\n  3 beds 3 baths 3 Toilets
# 1                          \nFurnished\n  4 beds 4 baths 5 Toilets
# 2                          \nFurnished\n  2 beds 2 baths 2 Toilets
# 3                          \nFurnished\n  3 beds 3 baths 3 Toilets
# 4                \nFurnished\nServiced\n  5 beds 5 baths 5 Toilets
# 5                          \nFurnished\n  4 beds 4 baths 4 Toilets
# 6                          \nFurnished\n  3 beds 3 baths 3 Toilets
# 7                          \nFurnished\n  1 beds 1 baths 1 Toilets
# 8                          \nFurnished\n  3 beds 3 baths 3 Toilets
# 9                \nFurnished\nServiced\n    3 beds  baths  Toilets
# 10               \nFurnished\nServiced\n  3 beds 3 baths 4 Toilets
# 11                         \nFurnished\n  5 beds 5 baths 5 Toilets
# 12                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 13                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 14                                    \n  2 beds 3 baths 3 Toilets
# 15                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 16                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 17               \nFurnished\nServiced\n  1 beds 1 baths 1 Toilets
# 18                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 19  \nFurnished\nServiced\nNewly Built\n  2 beds 2 baths 2 Toilets
# 20                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 21  \nFurnished\nServiced\nNewly Built\n  2 beds 2 baths 2 Toilets
# 22                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 23                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 24                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 25                         \nFurnished\n  4 beds 4 baths 4 Toilets
# 26                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 27                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 28                         \nFurnished\n  5 beds 5 baths 5 Toilets
# 29                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 30                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 31                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 32                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 33                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 34                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 35                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 36                       \nNewly Built\n  2 beds 2 baths 3 Toilets
# 37                                    \n  1 beds 1 baths 1 Toilets
# 38                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 39                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 40                                    \n    4 beds  baths  Toilets
# 41                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 42                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 43                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 44                         \nFurnished\n  3 beds 3 baths 3 Toilets
# 45                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 46                         \nFurnished\n  1 beds 1 baths 1 Toilets
# 47                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 48                         \nFurnished\n  2 beds 2 baths 2 Toilets
# 49                         \nFurnished\n  3 beds 3 baths 3 Toilets
#
#     newly_built  serviced  furnished
# 0         False     False       True
# 1         False     False       True
# 2         False     False       True
# 3         False     False       True
# 4         False      True       True
# 5         False     False       True
# 6         False     False       True
# 7         False     False       True
# 8         False     False       True
# 9         False      True       True
# 10        False      True       True
# 11        False     False       True
# 12        False     False       True
# 13        False     False       True
# 14        False     False      False
# 15        False     False       True
# 16        False     False       True
# 17        False      True       True
# 18        False     False       True
# 19         True      True       True
# 20        False     False       True
# 21         True      True       True
# 22        False     False       True
# 23        False     False       True
# 24        False     False       True
# 25        False     False       True
# 26        False     False       True
# 27        False     False       True
# 28        False     False       True
# 29        False     False       True
# 30        False     False       True
# 31        False     False       True
# 32        False     False       True
# 33        False     False       True
# 34        False     False       True
# 35        False     False       True
# 36         True     False      False
# 37        False     False      False
# 38        False     False       True
# 39        False     False       True
# 40        False     False      False
# 41        False     False       True
# 42        False     False       True
# 43        False     False       True
# 44        False     False       True
# 45        False     False       True
# 46        False     False       True
# 47        False     False       True
# 48        False     False       True
# 49        False     False       True
